# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
# %matplotlib inline
plt.style.use('ggplot')

# %%
fraud_card= pd.read_csv('Downloads\creditcard.csv')

# %%
fraud_card.info
# Out:
# <bound method DataFrame.info of             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
fraud_card.isnull().values.any()
# Out:
# False

# %%
fraud_card.dropna()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
fraud_card['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
is_fraud=fraud_card['Class'].value_counts()[1]

# %%
not_fraud=fraud_card['Class'].value_counts()[0]

# %%
corr = fraud_card.corr()
corr
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.697350e-17 -1.424390e-15  1.755316e-17
# V2     -0.010593  4.697350e-17  1.000000e+00  2.512175e-16 -1.126388e-16
# V3     -0.419618 -1.424390e-15  2.512175e-16  1.000000e+00 -3.416910e-16
# V4     -0.105260  1.755316e-17 -1.126388e-16 -3.416910e-16  1.000000e+00
# V5      0.173072  6.391162e-17 -2.039868e-16 -1.436514e-15 -1.940929e-15
# V6     -0.063016  2.398071e-16  5.024680e-16  1.431581e-15 -2.712659e-16
# V7      0.084714  1.991550e-15  3.966486e-16  2.168574e-15  1.556330e-16
# V8     -0.036949 -9.490675e-17 -4.413984e-17  3.433113e-16  5.195643e-16
# V9     -0.008660  2.169581e-16 -5.728718e-17 -4.233770e-16  3.859585e-16
# V10     0.030617  7.433820e-17 -4.782388e-16  6.289267e-16  6.055490e-16
# V11    -0.247689  2.438580e-16  9.468995e-16 -5.501758e-17 -2.083600e-16
# ...

# %%
corr = fraud_card.corr()
plt.figure(figsize=(12,10))
heat = sns.heatmap(data=corr)
plt.title('Heatmap of Correlation')
# Out:
# Text(0.5, 1.0, 'Heatmap of Correlation')

# %%
from sklearn.preprocessing import StandardScaler
scaled_time = StandardScaler().fit_transform(fraud_card[['Time']])

# %%
scaled_amount = StandardScaler().fit_transform(fraud_card[['Amount']])

# %%
scaled_dataframe_time=pd.DataFrame(data=scaled_time )

# %%
scaled_dataframe_amount=pd.DataFrame(data=scaled_amount )

# %%
type(scaled_dataframe_amount)
# Out:
# pandas.core.frame.DataFrame

# %%
fraud_card= pd.concat([fraud_card, scaled_dataframe_time, scaled_dataframe_amount],axis=1)

# %%
fraud_card
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V23       V24  \
# ...

# %%
fraud_card.drop(['Amount', 'Time'], axis=1, inplace=True)

# %%
fraud_card
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V22       V23  \
# ...

# %%
y = pd.DataFrame(fraud_card['Class'])

# %%
y.value_counts()
# Out:
# Class
# 0        284315
# 1           492
# dtype: int64

# %%
x=fraud_card

# %%
x
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V22       V23  \
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
models = {
    "LR": LinearRegression(),
    "KNNR" : KNeighborsRegressor(), 
    #"SVR": SVR(),
    "DT": DecisionTreeRegressor(),
    #"RF": RandomForestRegressor(),
}

# %%
for name, model in models.items():
    print(f'Using model: {name}')
    model.fit(x_train, y_train)
    print(f'Training Score: {model.score(x_train, y_train)}')
    print(f'Test Score: {model.score(x_test, y_test)}') 
    y_pred = model.predict(x_test)
    print(f'RMSE: {np.sqrt(mean_squared_error(y_test, y_pred))}')
    print('-----------------------------------------------------------')
# Out:
# Using model: LR
# Training Score: 1.0
# Test Score: 1.0
# RMSE: 4.582604847019416e-16
# -----------------------------------------------------------
# Using model: KNNR
# Training Score: 0.8369769763764816
# Test Score: 0.7681725822011416
# RMSE: 0.019953951412190987
# -----------------------------------------------------------
# Using model: DT
# Training Score: 1.0
# Test Score: 1.0
# RMSE: 0.0
# -----------------------------------------------------------
# Using model: RF
# <ipython-input-27-771a633d79ad>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train, y_train)
# Training Score: 1.0
# Test Score: 1.0
# RMSE: 0.0
# -----------------------------------------------------------

# %%
model = RandomForestRegressor()   ###### changable

model.fit(x_train, y_train)
# Out:
# <ipython-input-45-d663c9d81d9e>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train, y_train)
# RandomForestRegressor()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([1., 0., 0., ..., 0., 0., 0.])

# %%
x_test
# Out:
#                V1        V2         V3        V4         V5        V6  \
# 43428  -16.526507  8.584972 -18.649853  9.505594 -13.793819 -2.832404
# 49906    0.339812 -2.743745  -0.134070 -1.385729  -1.451413  1.015887
# 29474    1.399590 -0.590701   0.168619 -1.029950  -0.539806  0.040444
# 276481  -0.432071  1.647895  -1.669361 -0.349504   0.785785 -0.630647
# 278846   2.014160 -0.137394  -1.015839  0.327269  -0.182179 -0.956571
# ...           ...       ...        ...       ...        ...       ...
# 75723   -1.994348  1.503076  -0.365560  0.780223  -0.957956  0.038648
# 252263  -0.234567  0.733694   0.486250 -0.718186   0.782227 -0.788837
# 221246   0.040441 -0.109737  -1.266430  1.004783   2.223390 -0.670372
# 81910   -0.495048  0.991481   1.671584 -0.342474   0.470012 -0.348503
# 59490   -1.590486  0.992415  -0.512841  1.120752  -1.916756  3.142176
#
#                V7        V8        V9        V10  ...       V22       V23  \
# ...

# %%
y_test
# Out:
#         Class
# 43428       1
# 49906       0
# 29474       0
# 276481      0
# 278846      0
# ...       ...
# 75723       0
# 252263      0
# 221246      0
# 81910       0
# 59490       0
#
# [56962 rows x 1 columns]
