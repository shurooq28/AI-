# %%
import pandas as pd

# %%
log = pd.read_csv('sendy_logistics - sendy_logistics.csv')

# %%
log.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# ...

# %%
log.isna()
# Out:
#        Order No  User Id  Vehicle Type  Platform Type  Personal or Business  \
# 0         False    False         False          False                 False
# 1         False    False         False          False                 False
# 2         False    False         False          False                 False
# 3         False    False         False          False                 False
# 4         False    False         False          False                 False
# ...         ...      ...           ...            ...                   ...
# 21196     False    False         False          False                 False
# 21197     False    False         False          False                 False
# 21198     False    False         False          False                 False
# 21199     False    False         False          False                 False
# 21200     False    False         False          False                 False
#
# ...

# %%
log['Temperature'].notna()
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 21196     True
# 21197     True
# 21198     True
# 21199     True
# 21200     True
# Name: Temperature, Length: 21201, dtype: bool

# %%
log.loc['NewTemp'] = log['Temperature'].notna()
